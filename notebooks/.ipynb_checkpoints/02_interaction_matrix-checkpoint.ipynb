# %%
import pandas as pd

df = pd.read_parquet(
    "../data/processed/orders_clean.parquet"
)

print(df.shape)
# Out:
# (40142, 31)

# %%
interaction = (
    df.groupby(
        ["customerId", "skuNumber"]
    )["effective_qty"]
    .sum()
    .reset_index()
)

interaction.head()
# Out:
#   customerId skuNumber  effective_qty
# 0    USR-100  SKU00010              1
# 1    USR-100  SKU00060              1
# 2    USR-100  SKU00062              1
# 3    USR-100  SKU00086              1
# 4   USR-1000  SKU00030              1

# %%
print(
    "Interactions:",
    len(interaction)
)

print(
    "Retailers:",
    interaction["customerId"].nunique()
)

print(
    "Products:",
    interaction["skuNumber"].nunique()
)
# Out:
# Interactions: 25595
# Retailers: 4480
# Products: 184

# %%
matrix = interaction.pivot(
    index="customerId",
    columns="skuNumber",
    values="effective_qty"
).fillna(0)

matrix.shape
# Out:
# (4480, 184)

# %%
zeros = (matrix == 0).sum().sum()

total = (
    matrix.shape[0]
    * matrix.shape[1]
)

sparsity = (
    zeros / total
) * 100

print(
    f"Sparsity: {sparsity:.2f}%"
)
# Out:
# Sparsity: 96.90%

# %%
matrix.to_parquet(
    "../data/processed/interaction_matrix.parquet"
)

print("Saved")
# Out:
# Saved

# %%
sku_lookup = (
    df[
        [
            "skuNumber",
            "itemName",
            "brand",
            "category"
        ]
    ]
    .drop_duplicates()
)

sku_lookup.to_parquet(
    "../data/processed/sku_lookup.parquet",
    index=False
)

print("Saved")
# Out:
# Saved

# %%
top_products = (
    df.groupby("itemName")
    ["effective_qty"]
    .sum()
    .sort_values(
        ascending=False
    )
    .head(20)
)

top_products
# Out:
# itemName
# Rajnigandha 4g                           12782
# TZ 00 (with Silver) 0.45g                12771
# Rajnigandha 17g Zipper 1 Pcs             12635
# TZ 00 4.25g (6 Pcs)                       4993
# Rajnigandha 100g                          2896
# RG Pearl Elaichi MP Pouch 0.14g           1707
# Rajnigandha 17g Zipper IC                 1664
# RG Pearl Elaichi 1.4g Hanger              1401
# Pass Pass Meetha Magic 11.75g Hanger      1136
# Pass Pass Meetha Magic 2.2g (100 pcs)     1121
# TZ 00 10g TIN                              767
# Pulse Kachha Aam 175 Candy                 724
# Center Fresh                               671
# Center Fruit                               623
# Total Spearmint 5 Pcs                      609
# Bingo Tedhe Medhe                          595
# Jabsons Hing Jeera Peanuts                 524
# Alpenliebe Creamfills Butter Toffee        514
# RG Pearl Elaichi Hanger (6 pcs)            503
# Hell Energy Drink                          454
# Name: effective_qty, dtype: int64

# %%
matrix.shape
# Out:
# (4480, 184)

# %%
top_products.head(10)
# Out:
# itemName
# Rajnigandha 4g                           12782
# TZ 00 (with Silver) 0.45g                12771
# Rajnigandha 17g Zipper 1 Pcs             12635
# TZ 00 4.25g (6 Pcs)                       4993
# Rajnigandha 100g                          2896
# RG Pearl Elaichi MP Pouch 0.14g           1707
# Rajnigandha 17g Zipper IC                 1664
# RG Pearl Elaichi 1.4g Hanger              1401
# Pass Pass Meetha Magic 11.75g Hanger      1136
# Pass Pass Meetha Magic 2.2g (100 pcs)     1121
# Name: effective_qty, dtype: int64

# %%
matrix.shape
# Out:
# (4480, 184)
