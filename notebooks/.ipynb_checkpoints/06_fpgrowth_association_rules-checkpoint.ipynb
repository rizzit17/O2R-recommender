# %%
import pandas as pd

df = pd.read_parquet(
    "../data/processed/orders_clean.parquet"
)

print(df.shape)
# Out:
# (4048, 31)

# %%
pip install mlxtend
# Out:
# Requirement already satisfied: mlxtend in c:\users\rishit\desktop\o2r-recommender\venv\lib\site-packages (0.25.0)
# Requirement already satisfied: scipy>=1.16.3 in c:\users\rishit\desktop\o2r-recommender\venv\lib\site-packages (from mlxtend) (1.17.1)
# Requirement already satisfied: numpy>=2.3.5 in c:\users\rishit\desktop\o2r-recommender\venv\lib\site-packages (from mlxtend) (2.4.6)
# Requirement already satisfied: pandas>=2.3.3 in c:\users\rishit\desktop\o2r-recommender\venv\lib\site-packages (from mlxtend) (3.0.3)
# Requirement already satisfied: scikit-learn>=1.8.0 in c:\users\rishit\desktop\o2r-recommender\venv\lib\site-packages (from mlxtend) (1.9.0)
# Requirement already satisfied: matplotlib>=3.10.8 in c:\users\rishit\desktop\o2r-recommender\venv\lib\site-packages (from mlxtend) (3.11.0)
# Requirement already satisfied: joblib>=1.5.2 in c:\users\rishit\desktop\o2r-recommender\venv\lib\site-packages (from mlxtend) (1.5.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\rishit\desktop\o2r-recommender\venv\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\rishit\desktop\o2r-recommender\venv\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\rishit\desktop\o2r-recommender\venv\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\rishit\desktop\o2r-recommender\venv\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\rishit\desktop\o2r-recommender\venv\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (26.2)
# Requirement already satisfied: pillow>=9 in c:\users\rishit\desktop\o2r-recommender\venv\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\rishit\desktop\o2r-recommender\venv\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\rishit\desktop\o2r-recommender\venv\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\users\rishit\desktop\o2r-recommender\venv\lib\site-packages (from pandas>=2.3.3->mlxtend) (2026.2)
# Requirement already satisfied: six>=1.5 in c:\users\rishit\desktop\o2r-recommender\venv\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.10.8->mlxtend) (1.17.0)
# Requirement already satisfied: narwhals>=2.0.1 in c:\users\rishit\desktop\o2r-recommender\venv\lib\site-packages (from scikit-learn>=1.8.0->mlxtend) (2.22.1)
# Requirement already satisfied: threadpoolctl>=3.5.0 in c:\users\rishit\desktop\o2r-recommender\venv\lib\site-packages (from scikit-learn>=1.8.0->mlxtend) (3.6.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
baskets = (
    df.groupby("orderNumber")
    ["skuNumber"]
    .apply(list)
    .tolist()
)

len(baskets)
# Out:
# 1580

# %%
from mlxtend.preprocessing import (
    TransactionEncoder
)

te = TransactionEncoder()

basket_matrix = te.fit(
    baskets
).transform(
    baskets
)

basket_df = pd.DataFrame(
    basket_matrix,
    columns=te.columns_
)

basket_df.shape
# Out:
# (1580, 159)

# %%
from mlxtend.frequent_patterns import (
    fpgrowth
)

frequent_items = fpgrowth(
    basket_df,
    min_support=0.01,
    use_colnames=True
)

frequent_items.head()
# Out:
#     support               itemsets
# 0  0.018354    frozenset({SKU614})
# 1  0.079114  frozenset({SKU00084})
# 2  0.178481  frozenset({SKU00060})
# 3  0.173418  frozenset({SKU00086})
# 4  0.129747  frozenset({SKU00062})

# %%
from mlxtend.frequent_patterns import (
    association_rules
)

rules = association_rules(
    frequent_items,
    metric="confidence",
    min_threshold=0.2
)

rules.head()
# Out:
#                        antecedents            consequents  antecedent support  \
# 0            frozenset({SKU00084})  frozenset({SKU00060})            0.079114
# 1  frozenset({SKU00086, SKU00084})  frozenset({SKU00060})            0.011392
# 2  frozenset({SKU00084, SKU00060})  frozenset({SKU00086})            0.017089
# 3            frozenset({SKU00086})  frozenset({SKU00060})            0.173418
# 4            frozenset({SKU00060})  frozenset({SKU00086})            0.178481
#
#    consequent support   support  confidence      lift  representativity  \
# 0            0.178481  0.017089    0.216000  1.210213               1.0
# 1            0.178481  0.010759    0.944444  5.291568               1.0
# 2            0.173418  0.010759    0.629630  3.630711               1.0
# 3            0.178481  0.148101    0.854015  4.784904               1.0
# 4            0.173418  0.148101    0.829787  4.784904               1.0
#
#    leverage  conviction  zhangs_metric   jaccard  certainty  kulczynski
# 0  0.002968    1.047856       0.188622  0.071053   0.045670    0.155872
# 1  0.008726   14.787342       0.820366  0.060071   0.932375    0.502364
# 2  0.007796    2.231772       0.737169  0.059859   0.551926    0.345837
# 3  0.117149    5.627405       0.956964  0.726708   0.822298    0.841901
# 4  0.117149    4.856171       0.962862  0.726708   0.794076    0.841901

# %%
rules = (
    rules.sort_values(
        "lift",
        ascending=False
    )
)

rules[
    [
        "antecedents",
        "consequents",
        "support",
        "confidence",
        "lift"
    ]
].head(20)
# Out:
#                         antecedents                  consequents   support  \
# 32              frozenset({SKUNK8})  frozenset({SKUNK3, SKUNK2})  0.010127
# 31      frozenset({SKUNK3, SKUNK2})          frozenset({SKUNK8})  0.010127
# 33              frozenset({SKUNK3})  frozenset({SKUNK8, SKUNK2})  0.010127
# 30      frozenset({SKUNK8, SKUNK2})          frozenset({SKUNK3})  0.010127
# 29      frozenset({SKUNK8, SKUNK3})          frozenset({SKUNK2})  0.010127
# 34              frozenset({SKUNK2})  frozenset({SKUNK8, SKUNK3})  0.010127
# 25              frozenset({SKUNK8})          frozenset({SKUNK3})  0.015190
# 26              frozenset({SKUNK3})          frozenset({SKUNK8})  0.015190
# 28              frozenset({SKUNK2})          frozenset({SKUNK8})  0.012025
# 27              frozenset({SKUNK8})          frozenset({SKUNK2})  0.012025
# 37              frozenset({SKUNK3})          frozenset({SKUNK2})  0.012025
# 38              frozenset({SKUNK2})          frozenset({SKUNK3})  0.012025
# 40              frozenset({SKU613})          frozenset({SKU612})  0.017722
# 39              frozenset({SKU612})          frozenset({SKU613})  0.017722
# 20            frozenset({SKU00075})        frozenset({SKU00010})  0.012025
# 1   frozenset({SKU00086, SKU00084})        frozenset({SKU00060})  0.010759
# 4             frozenset({SKU00060})        frozenset({SKU00086})  0.148101
# 3             frozenset({SKU00086})        frozenset({SKU00060})  0.148101
# 8     frozenset({SKUPM4, SKU00060})        frozenset({SKU00086})  0.013924
# 14  frozenset({SKU00303, SKU00062})          frozenset({SKU080})  0.010759
#
#     confidence       lift
# 32    0.457143  38.015038
# 31    0.842105  38.015038
# 33    0.347826  28.924485
# 30    0.842105  28.924485
# 29    0.666667  27.008547
# 34    0.410256  27.008547
# 25    0.685714  23.552795
# 26    0.521739  23.552795
# 28    0.487179  21.992674
# 27    0.542857  21.992674
# 37    0.413043  16.733556
# 38    0.487179  16.733556
# 40    0.411765   6.505882
# 39    0.280000   6.505882
# 20    0.387755   5.519397
# 1     0.944444   5.291568
# 4     0.829787   4.784904
# 3     0.854015   4.784904
# 8     0.814815   4.698567
# 14    0.346939   4.685156

# %%
sku_lookup = (
    df[
        [
            "skuNumber",
            "itemName"
        ]
    ]
    .drop_duplicates()
)

sku_dict = dict(
    zip(
        sku_lookup["skuNumber"],
        sku_lookup["itemName"]
    )
)

# %%
rules["antecedent_names"] = (
    rules["antecedents"]
    .apply(
        lambda x:
        [
            sku_dict.get(i, i)
            for i in x
        ]
    )
)

rules["consequent_names"] = (
    rules["consequents"]
    .apply(
        lambda x:
        [
            sku_dict.get(i, i)
            for i in x
        ]
    )
)

# %%
rules[
    [
        "antecedent_names",
        "consequent_names",
        "confidence",
        "lift"
    ]
].head(20)
# Out:
#                                      antecedent_names  \
# 32                        [Jabsons Tandoori Peanuts ]
# 31  [Jabsons Hing Jeera Peanuts, Jabsons Green Pea...
# 33                       [Jabsons Hing Jeera Peanuts]
# 30  [Jabsons Tandoori Peanuts , Jabsons Green Peas...
# 29  [Jabsons Tandoori Peanuts , Jabsons Hing Jeera...
# 34                [Jabsons Green Peas onion & Garlic]
# 25                        [Jabsons Tandoori Peanuts ]
# 26                       [Jabsons Hing Jeera Peanuts]
# 28                [Jabsons Green Peas onion & Garlic]
# 27                        [Jabsons Tandoori Peanuts ]
# 37                       [Jabsons Hing Jeera Peanuts]
# 38                [Jabsons Green Peas onion & Garlic]
# 40                                     [Center Fresh]
# 39                                     [Center Fruit]
# 20                              [Tulsi Royal Khajoor]
# 1    [TZ 00 (with Silver) 0.45g, TZ 00 4.25g (6 Pcs)]
# 4                                   [Rajnigandha 4g ]
# 3                         [TZ 00 (with Silver) 0.45g]
# 8     [Rajnigandha 17g Zipper 1 Pcs, Rajnigandha 4g ]
# 14  [RG Pearl Elaichi 1.4g Hanger, RG Pearl Elaich...
#
#                                      consequent_names  confidence       lift
# 32  [Jabsons Hing Jeera Peanuts, Jabsons Green Pea...    0.457143  38.015038
# 31                        [Jabsons Tandoori Peanuts ]    0.842105  38.015038
# 33  [Jabsons Tandoori Peanuts , Jabsons Green Peas...    0.347826  28.924485
# 30                       [Jabsons Hing Jeera Peanuts]    0.842105  28.924485
# 29                [Jabsons Green Peas onion & Garlic]    0.666667  27.008547
# 34  [Jabsons Tandoori Peanuts , Jabsons Hing Jeera...    0.410256  27.008547
# 25                       [Jabsons Hing Jeera Peanuts]    0.685714  23.552795
# 26                        [Jabsons Tandoori Peanuts ]    0.521739  23.552795
# 28                        [Jabsons Tandoori Peanuts ]    0.487179  21.992674
# 27                [Jabsons Green Peas onion & Garlic]    0.542857  21.992674
# 37                [Jabsons Green Peas onion & Garlic]    0.413043  16.733556
# 38                       [Jabsons Hing Jeera Peanuts]    0.487179  16.733556
# 40                                     [Center Fruit]    0.411765   6.505882
# 39                                     [Center Fresh]    0.280000   6.505882
# 20             [Pass Pass Meetha Magic 11.75g Hanger]    0.387755   5.519397
# 1                                   [Rajnigandha 4g ]    0.944444   5.291568
# 4                         [TZ 00 (with Silver) 0.45g]    0.829787   4.784904
# 3                                   [Rajnigandha 4g ]    0.854015   4.784904
# 8                         [TZ 00 (with Silver) 0.45g]    0.814815   4.698567
# 14            [Pass Pass Meetha Magic 2.2g (100 pcs)]    0.346939   4.685156

# %%
rules.to_parquet(
    "../data/processed/association_rules.parquet",
    index=False
)

print("Saved")
# Out:
# ----------------------------------------------------------------
# ArrowInvalid                   Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 rules.to_parquet(
#       2     "../data/processed/association_rules.parquet",
#       3     index=False
#       4 )
#
# File ~\Desktop\O2R-recommender\venv\Lib\site-packages\pandas\core\frame.py:3135, in DataFrame.to_parquet(self, path, engine, compression, index, partition_cols, storage_options, filesystem, **kwargs)
#    3131         >>> content = f.read()
#    3132         """
#    3133         from pandas.io.parquet import to_parquet
#    3134
# -> 3135         return to_parquet(
#    3136             self,
#    3137             path,
#    3138             engine,
#
# File ~\Desktop\O2R-recommender\venv\Lib\site-packages\pandas\io\parquet.py:490, in to_parquet(df, path, engine, compression, index, storage_options, partition_cols, filesystem, **kwargs)
#     486 impl = get_engine(engine)
#     488 path_or_buf: FilePath | WriteBuffer[bytes] = io.BytesIO() if path is None else path
# --> 490 impl.write(
#     491     df,
#     492     path_or_buf,
#     493     compression=compression,
#     494     index=index,
#     495     partition_cols=partition_cols,
#     496     storage_options=storage_options,
#     497     filesystem=filesystem,
#     498     **kwargs,
#     499 )
#     501 if path is None:
#     502     assert isinstance(path_or_buf, io.BytesIO)
#
# File ~\Desktop\O2R-recommender\venv\Lib\site-packages\pandas\io\parquet.py:191, in PyArrowImpl.write(self, df, path, compression, index, storage_options, partition_cols, filesystem, **kwargs)
#     188 if index is not None:
#     189     from_pandas_kwargs["preserve_index"] = index
# --> 191 table = self.api.Table.from_pandas(df, **from_pandas_kwargs)
#     193 if df.attrs:
#     194     df_metadata = {"PANDAS_ATTRS": json.dumps(df.attrs)}
#
# File pyarrow/table.pxi:4768, in pyarrow.lib.Table.from_pandas()
# -> 4768 'Could not get source, probably due dynamically evaluated source code.'
#
# File ~\Desktop\O2R-recommender\venv\Lib\site-packages\pyarrow\pandas_compat.py:651, in dataframe_to_arrays(df, schema, preserve_index, nthreads, columns, safe)
#     646     return (isinstance(arr, np.ndarray) and
#     647             arr.flags.contiguous and
#     648             issubclass(arr.dtype.type, np.integer))
#     650 if nthreads == 1:
# --> 651     arrays = [convert_column(c, f)
#     652               for c, f in zip(columns_to_convert, convert_fields)]
#     653 else:
#     654     arrays = []
#
# File ~\Desktop\O2R-recommender\venv\Lib\site-packages\pyarrow\pandas_compat.py:639, in dataframe_to_arrays.<locals>.convert_column(col, field)
#     634 except (pa.ArrowInvalid,
#     635         pa.ArrowNotImplementedError,
#     636         pa.ArrowTypeError) as e:
#     637     e.args += (
#     638         f"Conversion failed for column {col.name} with type {col.dtype}",)
# --> 639     raise e
#     640 if not field_nullable and result.null_count > 0:
#     641     raise ValueError(f"Field {field} was non-nullable but pandas column "
#     642                      f"had {result.null_count} null values")
#
# File ~\Desktop\O2R-recommender\venv\Lib\site-packages\pyarrow\pandas_compat.py:633, in dataframe_to_arrays.<locals>.convert_column(col, field)
#     630     type_ = field.type
#     632 try:
# --> 633     result = pa.array(col, type=type_, from_pandas=True, safe=safe)
#     634 except (pa.ArrowInvalid,
#     635         pa.ArrowNotImplementedError,
#     636         pa.ArrowTypeError) as e:
#     637     e.args += (
#     638         f"Conversion failed for column {col.name} with type {col.dtype}",)
#
# File pyarrow/array.pxi:390, in pyarrow.lib.array()
# --> 390 'Could not get source, probably due dynamically evaluated source code.'
#
# File pyarrow/array.pxi:91, in pyarrow.lib._ndarray_to_array()
# ---> 91 'Could not get source, probably due dynamically evaluated source code.'
#
# File pyarrow/error.pxi:92, in pyarrow.lib.check_status()
# ---> 92 'Could not get source, probably due dynamically evaluated source code.'
#
# ArrowInvalid: ("Could not convert frozenset({'SKUNK8'}) with type frozenset: did not recognize Python value type when inferring an Arrow data type", 'Conversion failed for column antecedents with type object')

# %%
print(rules.shape)

rules[
    [
        "antecedent_names",
        "consequent_names",
        "confidence",
        "lift"
    ]
].head(20)
# Out:
# (41, 16)
#                                      antecedent_names  \
# 32                        [Jabsons Tandoori Peanuts ]
# 31  [Jabsons Hing Jeera Peanuts, Jabsons Green Pea...
# 33                       [Jabsons Hing Jeera Peanuts]
# 30  [Jabsons Tandoori Peanuts , Jabsons Green Peas...
# 29  [Jabsons Tandoori Peanuts , Jabsons Hing Jeera...
# 34                [Jabsons Green Peas onion & Garlic]
# 25                        [Jabsons Tandoori Peanuts ]
# 26                       [Jabsons Hing Jeera Peanuts]
# 28                [Jabsons Green Peas onion & Garlic]
# 27                        [Jabsons Tandoori Peanuts ]
# 37                       [Jabsons Hing Jeera Peanuts]
# 38                [Jabsons Green Peas onion & Garlic]
# 40                                     [Center Fresh]
# 39                                     [Center Fruit]
# 20                              [Tulsi Royal Khajoor]
# 1    [TZ 00 (with Silver) 0.45g, TZ 00 4.25g (6 Pcs)]
# 4                                   [Rajnigandha 4g ]
# 3                         [TZ 00 (with Silver) 0.45g]
# 8     [Rajnigandha 17g Zipper 1 Pcs, Rajnigandha 4g ]
# 14  [RG Pearl Elaichi 1.4g Hanger, RG Pearl Elaich...
#
#                                      consequent_names  confidence       lift
# 32  [Jabsons Hing Jeera Peanuts, Jabsons Green Pea...    0.457143  38.015038
# 31                        [Jabsons Tandoori Peanuts ]    0.842105  38.015038
# 33  [Jabsons Tandoori Peanuts , Jabsons Green Peas...    0.347826  28.924485
# 30                       [Jabsons Hing Jeera Peanuts]    0.842105  28.924485
# 29                [Jabsons Green Peas onion & Garlic]    0.666667  27.008547
# 34  [Jabsons Tandoori Peanuts , Jabsons Hing Jeera...    0.410256  27.008547
# 25                       [Jabsons Hing Jeera Peanuts]    0.685714  23.552795
# 26                        [Jabsons Tandoori Peanuts ]    0.521739  23.552795
# 28                        [Jabsons Tandoori Peanuts ]    0.487179  21.992674
# 27                [Jabsons Green Peas onion & Garlic]    0.542857  21.992674
# 37                [Jabsons Green Peas onion & Garlic]    0.413043  16.733556
# 38                       [Jabsons Hing Jeera Peanuts]    0.487179  16.733556
# 40                                     [Center Fruit]    0.411765   6.505882
# 39                                     [Center Fresh]    0.280000   6.505882
# 20             [Pass Pass Meetha Magic 11.75g Hanger]    0.387755   5.519397
# 1                                   [Rajnigandha 4g ]    0.944444   5.291568
# 4                         [TZ 00 (with Silver) 0.45g]    0.829787   4.784904
# 3                                   [Rajnigandha 4g ]    0.854015   4.784904
# 8                         [TZ 00 (with Silver) 0.45g]    0.814815   4.698567
# 14            [Pass Pass Meetha Magic 2.2g (100 pcs)]    0.346939   4.685156

# %%
rules_save["antecedents"] = (
    rules_save["antecedents"]
    .astype(str)
)

rules_save["consequents"] = (
    rules_save["consequents"]
    .astype(str)
)

rules_save["antecedent_names"] = (
    rules_save["antecedent_names"]
    .astype(str)
)

rules_save["consequent_names"] = (
    rules_save["consequent_names"]
    .astype(str)
)
# Out:
# ----------------------------------------------------------------
# NameError                      Traceback (most recent call last)
# Cell In[14], line 2
#       1 rules_save["antecedents"] = (
# ----> 2     rules_save["antecedents"]
#       3     .astype(str)
#       4 )
#       5
#
# NameError: name 'rules_save' is not defined

# %%
rules_save = rules.copy()

# %%
rules_save["antecedents"] = (
    rules_save["antecedents"]
    .astype(str)
)

rules_save["consequents"] = (
    rules_save["consequents"]
    .astype(str)
)

rules_save["antecedent_names"] = (
    rules_save["antecedent_names"]
    .astype(str)
)

rules_save["consequent_names"] = (
    rules_save["consequent_names"]
    .astype(str)
)

# %%
rules_save.to_parquet(
    "../data/processed/association_rules.parquet",
    index=False
)

print("Association rules saved")
# Out:
# Association rules saved

# %%
rules[
    [
        "antecedent_names",
        "consequent_names",
        "confidence",
        "lift"
    ]
].head(20)
# Out:
#                                      antecedent_names  \
# 32                        [Jabsons Tandoori Peanuts ]
# 31  [Jabsons Hing Jeera Peanuts, Jabsons Green Pea...
# 33                       [Jabsons Hing Jeera Peanuts]
# 30  [Jabsons Tandoori Peanuts , Jabsons Green Peas...
# 29  [Jabsons Tandoori Peanuts , Jabsons Hing Jeera...
# 34                [Jabsons Green Peas onion & Garlic]
# 25                        [Jabsons Tandoori Peanuts ]
# 26                       [Jabsons Hing Jeera Peanuts]
# 28                [Jabsons Green Peas onion & Garlic]
# 27                        [Jabsons Tandoori Peanuts ]
# 37                       [Jabsons Hing Jeera Peanuts]
# 38                [Jabsons Green Peas onion & Garlic]
# 40                                     [Center Fresh]
# 39                                     [Center Fruit]
# 20                              [Tulsi Royal Khajoor]
# 1    [TZ 00 (with Silver) 0.45g, TZ 00 4.25g (6 Pcs)]
# 4                                   [Rajnigandha 4g ]
# 3                         [TZ 00 (with Silver) 0.45g]
# 8     [Rajnigandha 17g Zipper 1 Pcs, Rajnigandha 4g ]
# 14  [RG Pearl Elaichi 1.4g Hanger, RG Pearl Elaich...
#
#                                      consequent_names  confidence       lift
# 32  [Jabsons Hing Jeera Peanuts, Jabsons Green Pea...    0.457143  38.015038
# 31                        [Jabsons Tandoori Peanuts ]    0.842105  38.015038
# 33  [Jabsons Tandoori Peanuts , Jabsons Green Peas...    0.347826  28.924485
# 30                       [Jabsons Hing Jeera Peanuts]    0.842105  28.924485
# 29                [Jabsons Green Peas onion & Garlic]    0.666667  27.008547
# 34  [Jabsons Tandoori Peanuts , Jabsons Hing Jeera...    0.410256  27.008547
# 25                       [Jabsons Hing Jeera Peanuts]    0.685714  23.552795
# 26                        [Jabsons Tandoori Peanuts ]    0.521739  23.552795
# 28                        [Jabsons Tandoori Peanuts ]    0.487179  21.992674
# 27                [Jabsons Green Peas onion & Garlic]    0.542857  21.992674
# 37                [Jabsons Green Peas onion & Garlic]    0.413043  16.733556
# 38                       [Jabsons Hing Jeera Peanuts]    0.487179  16.733556
# 40                                     [Center Fruit]    0.411765   6.505882
# 39                                     [Center Fresh]    0.280000   6.505882
# 20             [Pass Pass Meetha Magic 11.75g Hanger]    0.387755   5.519397
# 1                                   [Rajnigandha 4g ]    0.944444   5.291568
# 4                         [TZ 00 (with Silver) 0.45g]    0.829787   4.784904
# 3                                   [Rajnigandha 4g ]    0.854015   4.784904
# 8                         [TZ 00 (with Silver) 0.45g]    0.814815   4.698567
# 14            [Pass Pass Meetha Magic 2.2g (100 pcs)]    0.346939   4.685156

# %%
rules_save = rules.copy()

for col in [
    "antecedents",
    "consequents",
    "antecedent_names",
    "consequent_names"
]:
    rules_save[col] = rules_save[col].astype(str)

rules_save.to_csv(
    "../data/processed/association_rules.csv",
    index=False
)

# %%
print(rules.shape)
# Out:
# (41, 16)

# %%
rules.shape
# Out:
# (41, 16)
