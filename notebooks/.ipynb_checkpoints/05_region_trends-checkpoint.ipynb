# %%
import pandas as pd

df = pd.read_parquet(
    "../data/processed/orders_clean.parquet"
)

print(df.shape)
# Out:
# (40142, 31)

# %%
df["hubName"].value_counts()
# Out:
# hubName
# Instant Foods(Noida)             8996
# Instant Foods (SED)              5301
# Crossline Events (Noida)         4287
# Instant Foods (GZB)              4160
# Cross Line Events (Ghaziabad)    3878
# Rapid Enterprises                3774
# Cross Line Events (EDelhi)       3720
# Crossline Events (Meerut)        3452
# NB Enterprises (West Delhi)      2574
# Name: count, dtype: int64

# %%
region_trends = (
    df.groupby(
        [
            "hubId",
            "hubName",
            "shopType",
            "skuNumber"
        ]
    )
    .agg(
        total_qty=(
            "effective_qty",
            "sum"
        ),

        unique_buyers=(
            "customerId",
            "nunique"
        ),

        total_orders=(
            "orderNumber",
            "nunique"
        )
    )
    .reset_index()
)

region_trends.head()
# Out:
#    hubId               hubName   shopType skuNumber  total_qty  unique_buyers  \
# 0  HB002  Instant Foods(Noida)  Chemist C  SKU00060          5              2
# 1  HB002  Instant Foods(Noida)  Chemist C  SKU00062          4              1
# 2  HB002  Instant Foods(Noida)  Chemist C  SKU00067          1              1
# 3  HB002  Instant Foods(Noida)  Chemist C  SKU00084          3              1
# 4  HB002  Instant Foods(Noida)  Chemist C  SKU00086          5              2
#
#    total_orders
# 0             3
# 1             2
# 2             1
# 3             2
# 4             3

# %%
sku_lookup = (
    df[
        [
            "skuNumber",
            "itemName",
            "brand",
            "category"
        ]
    ]
    .drop_duplicates()
)

region_trends = (
    region_trends.merge(
        sku_lookup,
        on="skuNumber",
        how="left"
    )
)

region_trends.head()
# Out:
#    hubId               hubName   shopType skuNumber  total_qty  unique_buyers  \
# 0  HB002  Instant Foods(Noida)  Chemist C  SKU00060          5              2
# 1  HB002  Instant Foods(Noida)  Chemist C  SKU00062          4              1
# 2  HB002  Instant Foods(Noida)  Chemist C  SKU00067          1              1
# 3  HB002  Instant Foods(Noida)  Chemist C  SKU00084          3              1
# 4  HB002  Instant Foods(Noida)  Chemist C  SKU00086          5              2
#
#    total_orders                         itemName         brand  \
# 0             3                  Rajnigandha 4g   Rajnigandha
# 1             2  RG Pearl Elaichi MP Pouch 0.14g      DS Group
# 2             1      RG Pearl Elaichi 0.14g Jar       DS Group
# 3             2              TZ 00 4.25g (6 Pcs)         Tulsi
# 4             3        TZ 00 (with Silver) 0.45g         Tulsi
#
#            category
# 0        Pan Masala
# 1  Mouth Fresheners
# 2  Mouth Fresheners
# 3             Zarda
# 4             Zarda

# %%
region_trends[
    "region_rank"
] = (
    region_trends
    .groupby(
        [
            "hubId",
            "shopType"
        ]
    )
    ["unique_buyers"]
    .rank(
        ascending=False,
        method="dense"
    )
)

region_trends.head()
# Out:
#    hubId               hubName   shopType skuNumber  total_qty  unique_buyers  \
# 0  HB002  Instant Foods(Noida)  Chemist C  SKU00060          5              2
# 1  HB002  Instant Foods(Noida)  Chemist C  SKU00062          4              1
# 2  HB002  Instant Foods(Noida)  Chemist C  SKU00067          1              1
# 3  HB002  Instant Foods(Noida)  Chemist C  SKU00084          3              1
# 4  HB002  Instant Foods(Noida)  Chemist C  SKU00086          5              2
#
#    total_orders                         itemName         brand  \
# 0             3                  Rajnigandha 4g   Rajnigandha
# 1             2  RG Pearl Elaichi MP Pouch 0.14g      DS Group
# 2             1      RG Pearl Elaichi 0.14g Jar       DS Group
# 3             2              TZ 00 4.25g (6 Pcs)         Tulsi
# 4             3        TZ 00 (with Silver) 0.45g         Tulsi
#
#            category  region_rank
# 0        Pan Masala          1.0
# 1  Mouth Fresheners          2.0
# 2  Mouth Fresheners          2.0
# 3             Zarda          2.0
# 4             Zarda          1.0

# %%
(
    region_trends[
        region_trends["hubName"]
        == "Instant Foods(Noida)"
    ]
    .sort_values(
        "region_rank"
    )
    [
        [
            "itemName",
            "unique_buyers",
            "region_rank"
        ]
    ]
    .head(10)
)
# Out:
#                       itemName  unique_buyers  region_rank
# 17             Rajnigandha 4g              57          1.0
# 417  TZ 00 (with Silver) 0.45g            268          1.0
# 219  TZ 00 (with Silver) 0.45g            104          1.0
# 551        TZ 00 4.25g (6 Pcs)             37          1.0
# 4    TZ 00 (with Silver) 0.45g              2          1.0
# 331            Rajnigandha 4g              38          1.0
# 630            Rajnigandha 4g               3          1.0
# 632  TZ 00 (with Silver) 0.45g              3          1.0
# 547            Rajnigandha 4g              37          1.0
# 0              Rajnigandha 4g               2          1.0

# %%
region_trends.to_parquet(
    "../data/processed/region_trends.parquet",
    index=False
)

print("Saved")
# Out:
# Saved

# %%
print(region_trends.shape)

print(
    region_trends["hubName"]
    .nunique()
)

print(
    region_trends["shopType"]
    .nunique()
)
# Out:
# (4164, 11)
# 9
# 10

# %%
region_trends.shape
# Out:
# (4164, 11)

# %%
region_trends.sort_values(
    "region_rank"
)[
    [
        "hubName",
        "shopType",
        "itemName",
        "region_rank"
    ]
].head(15)
# Out:
#                        hubName    shopType                   itemName  \
# 0         Instant Foods(Noida)   Chemist C            Rajnigandha 4g
# 4154         Rapid Enterprises  Wholesaler  TZ 00 (with Silver) 0.45g
# 4152         Rapid Enterprises  Wholesaler            Rajnigandha 4g
# 3970         Rapid Enterprises      Paan A            Rajnigandha 4g
# 3886         Rapid Enterprises   General C            Rajnigandha 4g
# 897        Instant Foods (GZB)      Paan A            Rajnigandha 4g
# 826        Instant Foods (GZB)   General C  TZ 00 (with Silver) 0.45g
# 1119       Instant Foods (GZB)  Wholesaler  TZ 00 (with Silver) 0.45g
# 1068       Instant Foods (GZB)      Paan C  TZ 00 (with Silver) 0.45g
# 954        Instant Foods (GZB)      Paan B            Rajnigandha 4g
# 1130  Crossline Events (Noida)   General A            Rajnigandha 4g
# 1134  Crossline Events (Noida)   General A  TZ 00 (with Silver) 0.45g
# 1117       Instant Foods (GZB)  Wholesaler            Rajnigandha 4g
# 1255  Crossline Events (Noida)   General C  TZ 00 (with Silver) 0.45g
# 644        Instant Foods (GZB)   Chemist B               Center Fruit
#
#       region_rank
# 0             1.0
# 4154          1.0
# 4152          1.0
# 3970          1.0
# 3886          1.0
# 897           1.0
# 826           1.0
# 1119          1.0
# 1068          1.0
# 954           1.0
# 1130          1.0
# 1134          1.0
# 1117          1.0
# 1255          1.0
# 644           1.0

# %%
region_trends.shape
# Out:
# (4164, 11)
