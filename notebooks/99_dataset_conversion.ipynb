# %%
import pandas as pd

df = pd.read_excel(
    "../data/raw/orders_600K.xlsx"
)

print(df.shape)

df.to_parquet(
    "../data/raw/orders_600K.parquet"
)

print("Done")
# Out:
# (609723, 30)
# Done
